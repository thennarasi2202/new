# %% [markdown]
# <a href="https://colab.research.google.com/github/thennarasi2202/new/blob/main/shopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install pandas numpy matplotlib seaborn scikit-learn

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
try:
    df = pd.read_csv('WhatsgoodlyData-6.csv')
    print(df.head())  # Print the first few rows to verify
except FileNotFoundError:
    print("Error: 'WhatsgoodlyData-6.csv' not found in the current directory.")
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    index                                           Question Segment Type  \
# 0      0  What social platform has influenced your onlin...       Mobile
# 1      1  What social platform has influenced your onlin...       Mobile
# 2      2  What social platform has influenced your onlin...       Mobile
# 3      3  What social platform has influenced your onlin...       Mobile
# 4      4  What social platform has influenced your onlin...       Mobile
#
#   Segment Description     Answer  Count  Percentage
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 2      Global results   Snapchat     86       0.032
# 3      Global results    Twitter    179       0.067
# 4      Global results        NaN    947       0.354

# %%
#display first five datapoints

df1 = pd.read_csv('WhatsgoodlyData-6.csv')
df1.head(5)
# Out:
#    index                                           Question Segment Type  \
# 0      0  What social platform has influenced your onlin...       Mobile
# 1      1  What social platform has influenced your onlin...       Mobile
# 2      2  What social platform has influenced your onlin...       Mobile
# 3      3  What social platform has influenced your onlin...       Mobile
# 4      4  What social platform has influenced your onlin...       Mobile
#
#   Segment Description     Answer  Count  Percentage
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 2      Global results   Snapchat     86       0.032
# 3      Global results    Twitter    179       0.067
# 4      Global results        NaN    947       0.354

# %%
#no of columns in the data

df1.shape
# Out:
# (1450, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1450 non-null   int64
#  1   Question             1450 non-null   object
#  2   Segment Type         1450 non-null   object
#  3   Segment Description  1450 non-null   object
#  4   Answer               1160 non-null   object
#  5   Count                1450 non-null   int64
#  6   Percentage           1450 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 79.4+ KB

# %%
df1.columns
# Out:
# Index(['index', 'Segment Type', 'Segment Description', 'Answer', 'Count',
#        'Percentage'],
#       dtype='object')

# %%
df1.rename(columns={'Question':'question',
                    'Segment Type':'seg_type',
                    'Segment Description':'seg_des',
                    'Answer':'ans',
                    'Count':'count',
                    'Percentage':'percent'}, inplace=True)

# %%
df1.isnull().sum()
# Out:
# index         0
# seg_type      0
# seg_des       0
# ans         290
# count         0
# percent       0
# dtype: int64

# %%
sns.displot(df1['seg_type'])
sns.set_style("whitegrid", {"grid.color": ".6", "grid.linestyle": ":"})
print(df1['seg_type'].value_counts(normalize=True))

plt.yscale('log')
plt.show()
# Out:
# seg_type
# University    0.600000
# Custom        0.386207
# Gender        0.006897
# Mobile        0.003448
# Web           0.003448
# Name: proportion, dtype: float64
